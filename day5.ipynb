# %% [markdown]
# <a href="https://colab.research.google.com/github/varshini2427/Data-Analytics-using-Python-Project/blob/main/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.Series([10,20,30,40])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
data=pd.Series([100,200,300],
             index=["VARSH","NAVI","NAMBU"]  )
print(data)
# Out:
# VARSH    100
# NAVI     200
# NAMBU    300
# dtype: int64

# %%
import pandas as pd

employee = {
    "ID": [101, 102, 103],
    "NAME": [" JENIFER", "ISHU", "THIVYA"],
    "Salary": [50000, 60000, 55000]
}

df = pd.DataFrame(employee)

print(df)
# Out:
#     ID      NAME  Salary
# 0  101   JENIFER   50000
# 1  102      ISHU   60000
# 2  103    THIVYA   55000

# %%
import pandas as pd

# Create product sales dataset
data = {
    "Product": ["Pen", "Pencil", "Book", "Eraser"],
    "Sales": [200, 150, 500, 100]
}

df = pd.DataFrame(data)

# Display dataset
print("Product Sales Dataset")
print(df)

# Total sales
print("\nTotal Sales:", df["Sales"].sum())

# Average sales
print("Average Sales:", df["Sales"].mean())

# Highest sales
print("Highest Sales:", df["Sales"].max())
# Out:
# Product Sales Dataset
#   Product  Sales
# 0     Pen    200
# 1  Pencil    150
# 2    Book    500
# 3  Eraser    100
#
# Total Sales: 950
# Average Sales: 237.5
# Highest Sales: 500
