# %% [markdown]
# <a href="https://colab.research.google.com/github/varshini2427/Data-Analytics-using-Python-Project/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1=int(input("enter mark 1:"))
mark2=int(input("enter mark 2:"))
mark3=int(input("enter mark 3:"))
total=mark1+mark2+mark3
average=total/3
print("total:",total)
print("average:",average)
if average>=50:
    print("pass")
else:
        print("fail")
# Out:
# enter mark 1:86
# enter mark 2:92
# enter mark 3:87
# total: 265
# average: 88.33333333333333
# pass

# %%
tamil = 90
english = 85
maths = 95
science = 88
social = 92

total = tamil + english + maths + science + social

print("Tamil =", tamil)
print("English =", english)
print("Maths =", maths)
print("Science =", science)
print("Social =", social)

print("Total Marks =", total)

if total >= 450:
    print("Grade : A+")
elif total >= 400:
    print("Grade : A")
elif total >= 350:
    print("Grade : B")
elif total >= 250:
    print("Grade : C")
elif total >= 175:
    print("Grade : Pass")
else:
    print("Grade : Fail")
# Out:
# Tamil = 90
# English = 85
# Maths = 95
# Science = 88
# Social = 92
# Total Marks = 450
# Grade : A+
